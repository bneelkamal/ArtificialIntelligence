# %% [markdown]
# <a href="https://colab.research.google.com/github/bneelkamal/ArtificialIntelligence/blob/AI/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple Linear Regression**

# %% [markdown]
# **Ice Cream Business Revenue Prediction based on Outside Temperature**
#
# Input X - Outside Air Temperature
# Outpur Y - Overall Daily Revenue generated in INR

# %%
import pandas as pd #for dataframe manipulations like excel in python , deal with tabular data
import numpy as np  #for numerical analysis , to deal with arrays
import seaborn as sns # for data visualisation
import matplotlib.pyplot as plt #for data visualisation

# %%
sales_df = pd.read_csv("https://raw.githubusercontent.com/bneelkamal/ArtificialIntelligence/main/LinearRegression/IceCreamData.csv")

# %%
sales_df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
sales_df.head(7)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194
# 5    14.352514  367.940744
# 6    13.707780  308.894518

# %%
sales_df.tail(8)
# Out:
#      Temperature     Revenue
# 492    23.056214  552.819351
# 493    14.931506  377.430928
# 494    25.112066  571.434257
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sales_df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
sales_df.mean()
# Out:
# Temperature     22.232225
# Revenue        521.570777
# dtype: float64

# %%
sales_df.max()
# Out:
# Temperature      45.0
# Revenue        1000.0
# dtype: float64

# %%
sales_df.min()
# Out:
# Temperature     0.0
# Revenue        10.0
# dtype: float64
